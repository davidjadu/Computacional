# %%
# %pylab inline
from scipy.fftpack import fftfreq, fft
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
data = np.loadtxt('circulos.dat')
x=data[:,0]
y=data[:,1]

# %%
data = np.loadtxt('circulos.dat')
x=data[:,0]
y=data[:,1]

# %%
scatter(x,y,alpha=0.5,s=0.2)
