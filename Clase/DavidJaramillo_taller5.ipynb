# %%
pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
n_points  = 1024
rand_signal  = random.random(n_points) 
rand_signal = rand_signal -  np.mean(rand_signal)
plot(rand_signal)

# %%
from scipy.fftpack import fft, fftfreq
fft_rand_signal = fft(rand_signal) / n_points 
freq = fftfreq(n_points, 1) 
plt.plot(freq,np.abs(fft_rand_signal))
plt.xlim(-0.05,0.05)
# Out:
# (-0.05, 0.05)

# %%
half_n = np.ceil(n_points/2.0)
fft_rand_signal_half = (2.0) * fft_rand_signal[:half_n]
freq_half = freq[:half_n]

# %%
scatter(freq_half, log10(np.absolute(fft_rand_signal_half)**2)) 
plt.xlim([0.01,0.5])
plt.ylim([-6,-1])
# Out:
# (-6, -1)

# %%
white_noise = fft_rand_signal/abs(fft_rand_signal)
plot(abs(white_noise))

# %%
f_withe_noise = ifft(white_noise)
plot(abs(f_withe_noise))

# %% [markdown]
# Se observa que el ruido blanco produce una señal que no sigue un patrón, es totalmente arbitraría

# %%
plot(rand_signal)
plot(abs(f_withe_noise),'r')
