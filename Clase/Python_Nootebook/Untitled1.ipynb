# %%
from scipy.interpolate import interp1d
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
x= random.random(100)

# %%
print x
# Out:
# [ 0.77527501  0.5520701   0.27990468  0.82362114  0.07134464  0.73625267
#   0.34497921  0.82408783  0.98449113  0.94772372  0.29467471  0.28924115
#   0.88643434  0.92496606  0.6952079   0.82700437  0.09200369  0.90272567
#   0.00169227  0.33652343  0.1642088   0.72490149  0.71696274  0.27383305
#   0.59521996  0.42776845  0.0621556   0.41316343  0.78074965  0.07776836
#   0.29213005  0.70258806  0.89269831  0.55066674  0.4620649   0.42416597
#   0.9305839   0.53563315  0.79801729  0.19258609  0.07407068  0.44220555
#   0.85550838  0.75996038  0.90696773  0.20751003  0.47409202  0.0914585
#   0.37800546  0.2057481   0.44004307  0.15076818  0.40196763  0.03497199
#   0.0960887   0.42745174  0.7881981   0.1385318   0.26186472  0.59544604
#   0.22530158  0.73915354  0.46550165  0.49195582  0.15551007  0.24564973
#   0.10913169  0.03676251  0.72205999  0.58721155  0.9295465   0.29615506
#   0.75042885  0.46150642  0.40744247  0.5171906   0.13244964  0.8588179
#   0.20983306  0.29038681  0.29536855  0.69173083  0.09527626  0.58058715
#   0.92188303  0.22679461  0.28053432  0.75528411  0.83626505  0.70175175
#   0.70405815  0.03042985  0.92990169  0.84870197  0.29655844  0.72571826
#   0.69432234  0.24735277  0.15078679  0.30173791]

# %%
plot (x)
ax = axes()
ax.set_title("$\mathrm{Random}$")
filename = "Random"
savefig(filename + ".pdf", format = "pdf")

# %%
x=random.random(1000)
y=random.random(1000)
scatter(x,y, color ="red", alpha=0.5, s=5)
ax=axes()
ax.set_xlabel("$x$", fontsize = 12)
ax.set_ylabel("$y$", fontsize = 12)
ax.set_title("$\mathrm{Random 2D}$", fontsize = 12)
filename = "Random2D"
savefig(filename + ".pdf", format = "pdf")
